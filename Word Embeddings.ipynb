# %%
# https://medium.com/analytics-vidhya/basics-of-using-pre-trained-glove-vectors-in-python-d38905f356db

# %%
import numpy as np
from scipy import spatial
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import scipy
import pandas as pd

from sklearn.manifold import MDS

# %%
embeddings_dict = {}

# %%
embeddings_dict = {}
with open("glove.6B.300d.txt", 'r',encoding="utf-8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector

# %%
# finding similar vectors
def find_closest_embeddings(embedding):
    return sorted(embeddings_dict.keys(), key=lambda word: spatial.distance.euclidean(embeddings_dict[word], embedding))

# %%
find_closest_embeddings( embeddings_dict['water'] + embeddings_dict['lemon'])
# Out:
# ['lemon',
#  'water',
#  'juice',
#  'lime',
#  'salt',
#  'vinegar',
#  'bottled',
#  'boiling',
#  'dried',
#  'syrup',
#  'drink',
#  'ginger',
#  'sugar',
#  'dry',
#  'butter',
#  'milk',
#  'coconut',
#  'soda',
#  'drinking',
#  'seawater',
#  'pepper',
#  'liquid',
#  'garlic',
#  'orange',
#  'add',
#  'mixture',
#  'fresh',
#  'flavored',
#  'honey',
#  'sauce',
#  'cream',
#  'fruit',
#  'zest',
#  'vanilla',
#  'bottle',
#  'drain',
#  'fish',
#  'herbs',
#  'boil',
#  'tomato',
#  'taste',
#  'combine',
#  'olive',
#  'mix',
#  'cinnamon',
#  'ingredients',
#  'onion',
#  'citrus',
#  'shrimp',
#  'splash',
#  'vegetables',
#  'chocolate',
#  'bread',
#  'grapefruit',
#  'chilled',
#  'spray',
#  'mint',
#  'sand',
#  'cups',
#  'drops',
#  'extract',
#  'freshly',
#  'salty',
#  'yogurt',
#  'cooked',
#  'soup',
#  'mango',
#  'vegetable',
#  'filling',
#  'vodka',
#  'drinks',
#  'lemons',
#  'clean',
#  'pour',
#  'flour',
#  'broth',
#  'ground',
#  'potable',
#  'chicken',
#  'warm',
#  'sprinkle',
#  'hot',
#  'cucumber',
#  'spoon',
#  'well',
#  'washed',
#  'peel',
#  'flavor',
#  'cooking',
#  'enough',
#  'wash',
#  'peach',
#  'waters',
#  'cool',
#  'squeeze',
#  'filled',
#  'squeezed',
#  'sprinkling',
#  'cake',
#  'pond',
#  'mixing',
#  'stir',
#  'drained',
#  'sliced',
#  'food',
#  'green',
#  'juices',
#  'potatoes',
#  'pomegranate',
#  'salted',
#  'pineapple',
#  'slices',
#  'scoop',
#  'beans',
#  'noodles',
#  'bring',
#  'cover',
#  'powdered',
#  'heat',
#  'ice',
#  'canned',
#  'bottles',
#  'lavender',
#  'scented',
#  'sour',
#  'cubes',
#  'and',
#  'gently',
#  'tea',
#  'cans',
#  'shallow',
#  'brine',
#  'onions',
#  'wine',
#  'almonds',
#  'cold',
#  'ocean',
#  'like',
#  'soak',
#  'soaked',
#  'trees',
#  'cheese',
#  'egg',
#  'slice',
#  'chopped',
#  'glass',
#  'large',
#  'melted',
#  'soft',
#  'spices',
#  'use',
#  'irrigation',
#  'remove',
#  'carrots',
#  'springs',
#  'combination',
#  'eat',
#  'drop',
#  'dip',
#  'supply',
#  'preferably',
#  'mustard',
#  'spinach',
#  'sea',
#  'iced',
#  'pasta',
#  'carrot',
#  'mud',
#  'rum',
#  'dressing',
#  'almond',
#  'buckets',
#  'stream',
#  'concoction',
#  'eggs',
#  'groundwater',
#  'strawberries',
#  'thick',
#  'shade',
#  '1',
#  'adding',
#  'watermelon',
#  'turn',
#  'little',
#  'bottom',
#  'keep',
#  'curd',
#  'glaze',
#  'so',
#  'comes',
#  'colored',
#  'wedges',
#  'cranberry',
#  'small',
#  'instead',
#  'molasses',
#  'cherry',
#  'sewage',
#  'half',
#  'then',
#  'covered',
#  'natural',
#  'pouring',
#  '2',
#  'etc.',
#  'melon',
#  'uses',
#  'addition',
#  'boiled',
#  'lots',
#  'few',
#  'brandy',
#  'flowing',
#  'yellow',
#  'ponds',
#  'put',
#  'fountain',
#  'baked',
#  'remaining',
#  'sponge',
#  'cook',
#  'only',
#  'serve',
#  'cooling',
#  'surface',
#  'just',
#  'mist',
#  'sweet',
#  'medium',
#  'example',
#  'leaves',
#  'moisture',
#  'makes',
#  'soil',
#  'drainage',
#  'mushrooms',
#  'berries',
#  'such',
#  'sparkling',
#  'extra',
#  'needed',
#  'place',
#  'using',
#  'fruits',
#  'cut',
#  'peanut',
#  'reservoirs',
#  'nuts',
#  'mayonnaise',
#  'one',
#  'oil',
#  'recipe',
#  'along',
#  'salad',
#  'instance',
#  'actually',
#  '1/3',
#  'lemonade',
#  'sprinkled',
#  'need',
#  'dish',
#  'fill',
#  'purpose',
#  'plenty',
#  'potato',
#  'even',
#  'drank',
#  'whole',
#  'them',
#  'nearby',
#  'light',
#  'occasionally',
#  'beer',
#  'contaminated',
#  'lightly',
#  '.',
#  'basil',
#  'oranges',
#  'pot',
#  'floating',
#  'until',
#  'coffee',
#  'used',
#  'tamarind',
#  'everything',
#  '?',
#  'celery',
#  'streams',
#  'quart',
#  ',',
#  'hence',
#  'paste',
#  'make',
#  'once',
#  'raisins',
#  'soy',
#  'refreshing',
#  'raw',
#  'saltwater',
#  'dill',
#  'infused',
#  'garnish',
#  'parsley',
#  'can',
#  'apples',
#  'mineral',
#  'or',
#  'pink',
#  'strips',
#  'cornstarch',
#  'grass',
#  'another',
#  'rub',
#  'creamy',
#  'tossed',
#  'thyme',
#  'brackish',
#  'avocado',
#  'sorbet',
#  'brown',
#  'the',
#  'desired',
#  'if',
#  '3',
#  'especially',
#  'sure',
#  'aside',
#  'because',
#  'up',
#  'reservoir',
#  'amount',
#  'lake',
#  'sesame',
#  'tart',
#  'brought',
#  'flavors',
#  'good',
#  'feeding',
#  'let',
#  'plastic',
#  'frozen',
#  'means',
#  'rind',
#  'spicy',
#  'tap',
#  'carbonated',
#  'eaten',
#  'red',
#  'buttermilk',
#  'distilled',
#  'bed',
#  'rosemary',
#  'except',
#  'you',
#  'underneath',
#  'simple',
#  'spring',
#  '__________________________________',
#  'whipped',
#  'cilantro',
#  'flesh',
#  'include',
#  'seltzer',
#  'chill',
#  'vinaigrette',
#  'sometimes',
#  'too',
#  'it',
#  'squirt',
#  'peaches',
#  'suck',
#  'piped',
#  'tangerine',
#  'anchovies',
#  'usually',
#  'tonic',
#  'bucket',
#  'cider',
#  'which',
#  'some',
#  'beneath',
#  'all',
#  'putting',
#  'directions',
#  'custard',
#  'abundance',
#  'baking',
#  'pools',
#  'pump',
#  'brush',
#  'come',
#  'rivers',
#  'bright',
#  'pear',
#  'things',
#  'pure',
#  'chili',
#  'figs',
#  'contain',
#  'flow',
#  'drizzle',
#  'wells',
#  'tablespoons',
#  'preserves',
#  'naturally',
#  'coming',
#  'contains',
#  'inland',
#  'with',
#  'essence',
#  'asparagus',
#  'eating',
#  'liqueur',
#  'containers',
#  '¼',
#  'sipping',
#  'sunlight',
#  'i-qula',
#  'mouth',
#  'but',
#  'into',
#  'puree',
#  'plus',
#  'float',
#  'bathing',
#  'icing',
#  'chestnuts',
#  'grated',
#  'tub',
#  'get',
#  'blended',
#  'container',
#  'salmon',
#  'rhubarb',
#  'tasting',
#  'other',
#  'soapy',
#  'source',
#  'when',
#  'stirring',
#  'slowly',
#  'fragrant',
#  'out',
#  'gallons',
#  'plain',
#  'nutrients',
#  'bath',
#  'blend',
#  'clear',
#  'turning',
#  'though',
#  'crisp',
#  'cleaned',
#  'touch',
#  'as',
#  'perhaps',
#  'provide',
#  'take',
#  'dripping',
#  'candy',
#  'toast',
#  'coriander',
#  'pie',
#  'alumhg',
#  'edible',
#  'peppers',
#  'delicious',
#  'fluid',
#  'produce',
#  'taken',
#  'seaweed',
#  'lobster',
#  'acidic',
#  'tree',
#  'gin',
#  'fluids',
#  'simply',
#  'poured',
#  'strawberry',
#  'submerged',
#  'much',
#  'cane',
#  'crust',
#  'bite',
#  'fennel',
#  'splashes',
#  'jars',
#  'verbena',
#  'banana',
#  'pool',
#  '4',
#  'lettuce',
#  'away',
#  'preserved',
#  'excess',
#  'way',
#  'scallops',
#  'pumps',
#  'oxygen',
#  'goes',
#  'containing',
#  'seeds',
#  'although',
#  'inside',
#  'something',
#  'pieces',
#  'bean',
#  'tuna',
#  'necessary',
#  'soaking',
#  'supplies',
#  'thin',
#  'raspberry',
#  'melt',
#  'pint',
#  'maybe',
#  'toss',
#  'feet',
#  'layer',
#  'bait',
#  'drying',
#  'supplied',
#  'plants',
#  'rather',
#  'meat',
#  'organic',
#  'wet',
#  'lemongrass',
#  'cakes',
#  'tossing',
#  'without',
#  'bag',
#  'always',
#  'sodas',
#  'tarragon',
#  'smell',
#  'stick',
#  'very',
#  'should',
#  'washing',
#  'pipe',
#  'pipes',
#  'apple',
#  '½',
#  'mussels',
#  'cube',
#  'meant',
#  'sage',
#  'dashst',
#  'absorb',
#  'provided',
#  'piece',
#  'dropping',
#  'hyacinth',
#  'poison',
#  'besides',
#  'cucumbers',
#  'cleaning',
#  'also',
#  'grape',
#  'ballast',
#  'again',
#  'corn',
#  'balsamic',
#  'hand',
#  'apricot',
#  'oregano',
#  'and/or',
#  'same',
#  '1/2',
#  'walnuts',
#  'ammonia',
#  'caramel',
#  'e.g.',
#  'splashing',
#  'essential',
#  'serves',
#  'coating',
#  'takes',
#  'cooled',
#  'liquids',
#  'nothing',
#  'dust',
#  'spills',
#  'color',
#  'breath',
#  'root',
#  'each',
#  'tangy',
#  'sink',
#  'helps',
#  'paint',
#  'resulting',
#  'temperature',
#  'gets',
#  'dipping',
#  'every',
#  'down',
#  'salinity',
#  'reduced',
#  'quarts',
#  'peppermint',
#  'goat',
#  'crystals',
#  'swimming',
#  'allow',
#  'seasoning',
#  'quality',
#  'why',
#  'is',
#  'prepared',
#  'lakes',
#  'immediately',
#  'amounts',
#  'available',
#  'gives',
#  'meaning',
#  'crab',
#  'stuff',
#  'fact',
#  'crackers',
#  'variety',
#  'pumpkin',
#  'ounces',
#  'bleach',
#  'oils',
#  '{',
#  'coolers',
#  'cooler',
#  'area',
#  'this',
#  'clam',
#  'kitchen',
#  'oatmeal',
#  'eggplant',
#  'squeezing',
#  'these',
#  'while',
#  'chlorine',
#  'tablespoon',
#  'chilies',
#  'peanuts',
#  'olives',
#  'walnut',
#  '—',
#  'mixes',
#  'roasted',
#  'gelatin',
#  'rain',
#  'substituting',
#  'scent',
#  'seafood',
#  'give',
#  'jar',
#  'jelly',
#  'reason',
#  'twist',
#  'eucalyptus',
#  'turns',
#  'additionally',
#  'conserve',
#  'dark',
#  'normally',
#  'wood',
#  'residents',
#  'above',
#  'both',
#  'combined',
#  'wetlands',
#  'limes',
#  'substitute',
#  'longer',
#  'sewer',
#  'literally',
#  'could',
#  'sticks',
#  'skin',
#  'of',
#  'onto',
#  'commonly',
#  'drinkable',
#  'chunks',
#  'shelter',
#  "'ll",
#  'together',
#  'evaporated',
#  'perfect',
#  'handful',
#  'land',
#  'sweetness',
#  'less',
#  'prevent',
#  'likes',
#  'dessert',
#  'cleaner',
#  'blossom',
#  'time',
#  'needs',
#  'more',
#  'kind',
#  'bowls',
#  '2/3',
#  'does',
#  'discard',
#  'rest',
#  'bubbles',
#  'where',
#  'thus',
#  'heated',
#  'jugs',
#  'latter',
#  '”',
#  'apart',
#  'polluted',
#  'contamination',
#  'pungent',
#  'room',
#  'leaf',
#  'river',
#  'anything',
#  'concentrated',
#  'sediment',
#  'watering',
#  'else',
#  'running',
#  '30',
#  'refrigerator',
#  'being',
#  'find',
#  'must',
#  'thing',
#  'bananas',
#  'fountains',
#  'chiles',
#  'there',
#  'products',
#  'that',
#  'almost',
#  'abundant',
#  'made',
#  'trout',
#  'bit',
#  'tender',
#  'turmeric',
#  'icy',
#  'extracts',
#  'blender',
#  'ate',
#  'meringue',
#  'others',
#  'really',
#  'adjacent',
#  'several',
#  'pudding',
#  'minced',
#  'quickly',
#  'either',
#  '10',
#  'removed',
#  'famous',
#  'additional',
#  'works',
#  'lily',
#  'big',
#  'tomatoes',
#  'no',
#  'sprays',
#  'freshwater',
#  'perfume',
#  'spiced',
#  'fig',
#  'fry',
#  'saline',
#  'k587-1',
#  'tequila',
#  'feed',
#  'passing',
#  'bulletinyyy',
#  'str95bb',
#  'k978-1',
#  'apricots',
#  'js94bb',
#  'bdb94',
#  'go',
#  'lovely',
#  'bb96',
#  'srivalo',
#  'piyanart',
#  'whatever',
#  'k977-1',
#  'ketchup',
#  'beets',
#  'mo95',
#  'anyway',
#  'spraying',
#  'http://www.mediabynumbers.com',
#  'concentrate',
#  'taking',
#  'still',
#  'cocktail',
#  'layers',
#  'basic',
#  'giving',
#  'places',
#  'curry',
#  'including',
#  'through',
#  'deep',
#  'thrown',
#  'low',
#  'typically',
#  'consistency',
#  'flavoring',
#  'hard',
#  'prepare',
#  'how',
#  'they',
#  'below',
#  'crushed',
#  'often',
#  'reduce',
#  'stains',
#  'areas',
#  'unlike',
#  'form',
#  'better',
#  'flakes',
#  'making',
#  'might',
#  'coke',
#  '65stk',
#  'toasted',
#  ';',
#  'everyone',
#  'noticed',
#  'back',
#  '5',
#  'surrounding',
#  'shampoo',
#  'consumed',
#  'burning',
#  'fertilizer',
#  'leaving',
#  'endtag',
#  'fine',
#  'freezing',
#  'softened',
#  'providing',
#  'local',
#  'whipping',
#  'whereas',
#  'blood',
#  'incorporate',
#  'pumping',
#  '_',
#  'supposed',
#  'sweetened',
#  'chop',
#  'however',
#  'dirt',
#  'portions',
#  'ones',
#  'explains',
#  'allowing',
#  'falling',
#  'over',
#  'mold',
#  'salts',
#  '[',
#  'produced',
#  'under',
#  'plum',
#  'swamp',
#  'liquor',
#  'puddle',
#  'pecans',
#  'beside',
#  'brohd',
#  'flows',
#  'similar',
#  'stems',
#  'nasdaq100',
#  'rice',
#  'grain',
#  'biscuits',
#  'indeed',
#  'part',
#  'hazelnut',
#  'walls',
#  'around',
#  'already',
#  'pine',
#  'plant',
#  'whenever',
#  "n't",
#  'resembles',
#  '“',
#  'measure',
#  'forth',
#  'provision',
#  'adapted',
#  'shortening',
#  'alternately',
#  'smelling',
#  'parts',
#  'herbal',
#  'result',
#  'kept',
#  'mousse',
#  'therefore',
#  'alumal',
#  'turned',
#  'halfway',
#  'whiskey',
#  'particularly',
#  'capers',
#  'pumped',
#  'exception',
#  'waste',
#  'in',
#  'balm',
#  'sunflower',
#  'hose',
#  'added',
#  'introduced',
#  'champagne',
#  'smooth',
#  'flavoured',
#  'provides',
#  'blue',
#  'extracted',
#  'shape',
#  'sprayed',
#  'bark',
#  'dishes',
#  'cloves',
#  'upstream',
#  'course',
#  'mean',
#  'flowed',
#  'ready',
#  'idea',
#  'ingredient',
#  'given',
#  'beaches',
#  'quite',
#  'shimmering',
#  'grown',
#  'easy',
#  'punch',
#  'bringing',
#  'keeping',
#  'bowl',
#  'contained',
#  'oysters',
#  'fingers',
#  'sprite',
#  'coral',
#  'creek',
#  'farmland',
#  'cookies',
#  'mashed',
#  'furthermore',
#  'warmed',
#  'tiny',
#  'pickle',
#  'solution',
#  'finely',
#  'what',
#  'keeps',
#  'got',
#  'kinds',
#  'empty',
#  'draining',
#  'letting',
#  'includes',
#  'couple',
#  'sanitation',
#  'prohertrib',
#  'purified',
#  'canals',
#  'martini',
#  'prawns',
#  'tube',
#  'heating',
#  'aroma',
#  'know',
#  'great',
#  'i.e.',
#  'fried',
#  'blossoms',
#  'vruhl',
#  'bricks',
#  'sherry',
#  'wonderful',
#  'spritz',
#  'came',
#  'sucking',
#  'toilet',
#  'seepage',
#  ...]

# %%
find_closest_embeddings(
(embeddings_dict['hotel']+embeddings_dict['room']+embeddings_dict['area']+embeddings_dict['time']
+embeddings_dict['location']+embeddings_dict['price']+embeddings_dict['day']+embeddings_dict['budget']
+embeddings_dict['year']+embeddings_dict['night'])/10 ) 


# find_closest_embeddings( embeddings_dict['tripadvisor'])
# Out:
# ['.',
#  'same',
#  'time',
#  ',',
#  'but',
#  'though',
#  'next',
#  'when',
#  'instance',
#  'although',
#  'even',
#  'once',
#  'addition',
#  'the',
#  'this',
#  'only',
#  'while',
#  'well',
#  'coming',
#  'prohertrib',
#  'last',
#  'where',
#  'just',
#  'which',
#  'so',
#  '__________________________________',
#  'however',
#  'days',
#  'one',
#  'actually',
#  'interbk',
#  'because',
#  'come',
#  'fact',
#  'piyanart',
#  'srivalo',
#  'bulletinyyy',
#  'str95bb',
#  'k978-1',
#  'js94bb',
#  'bb96',
#  'k977-1',
#  'mo95',
#  'k587-1',
#  'bdb94',
#  'instead',
#  'http://www.mediabynumbers.com',
#  'indeed',
#  'came',
#  'day',
#  'beginning',
#  'another',
#  '_____________________________________________',
#  'rest',
#  'week',
#  'example',
#  'before',
#  'put',
#  'month',
#  'in',
#  'http://www.nwguild.org',
#  'now',
#  'and',
#  'way',
#  'http://www.co.mo.md.us',
#  'also',
#  'both',
#  'after',
#  'taken',
#  'brought',
#  'unfortunately',
#  'meant',
#  'ago',
#  'already',
#  'kd97',
#  'yet',
#  'having',
#  'again',
#  'moreover',
#  'given',
#  'perhaps',
#  'few',
#  'leaving',
#  'that',
#  'em96',
#  '____________________________________________',
#  'alone',
#  '65stk',
#  'comes',
#  'noting',
#  '24aou94',
#  'as',
#  'followed',
#  'later',
#  'saw',
#  'likewise',
#  'year',
#  'what',
#  'part',
#  'it',
#  'probably',
#  'rather',
#  'seen',
#  'besides',
#  'bb94',
#  'up',
#  'first',
#  'adding',
#  'starting',
#  'weekend',
#  'present',
#  'night',
#  'supposed',
#  'taking',
#  'turned',
#  'presumably',
#  'there',
#  'soon',
#  'rw95',
#  'went',
#  'take',
#  'recently',
#  'took',
#  'kuhdz',
#  'place',
#  'result',
#  'then',
#  '10',
#  'much',
#  'today',
#  'str94',
#  'greg.wilcoxdailynews.com',
#  'here',
#  'months',
#  'gph04bb',
#  'earlier',
#  'bringing',
#  '30',
#  'js04bb',
#  'biotechtrst',
#  'anyway',
#  'putting',
#  'furthermore',
#  'latter',
#  'nevertheless',
#  'nothing',
#  'still',
#  'turn',
#  'they',
#  'all',
#  '20',
#  'following',
#  'giving',
#  'despite',
#  'prior',
#  'except',
#  'gone',
#  'weeks',
#  'additionally',
#  'referring',
#  'making',
#  'go',
#  'going',
#  'reason',
#  'others',
#  'http://www.oklahomacitynationalmemorial.org',
#  '#ukqec',
#  'either',
#  '30-270',
#  'thought',
#  '15',
#  'out',
#  'exception',
#  'ironically',
#  'far',
#  'meanwhile',
#  'similarly',
#  'years',
#  'finally',
#  'almost',
#  'meantime',
#  'every',
#  'nasdaq100tr',
#  'http://www.statoil.com',
#  'sure',
#  'least',
#  'likely',
#  'certainly',
#  'might',
#  'did',
#  'especially',
#  'particular',
#  'suggested',
#  'kind',
#  'www.slarmy.org',
#  'of',
#  'why',
#  'nortelnet',
#  'exactly',
#  'devonengy',
#  'nasdaq100',
#  'brohd',
#  'looking',
#  'end',
#  'back',
#  'decided',
#  'js03',
#  'would',
#  'simply',
#  'those',
#  'sort',
#  'wanted',
#  'bring',
#  'afterward',
#  'set',
#  'according',
#  'start',
#  'may',
#  'naborsind',
#  'possibly',
#  'noted',
#  'seeing',
#  'could',
#  'for',
#  'rohsh',
#  'find',
#  'most',
#  'svahng',
#  'make',
#  'some',
#  'setting',
#  'get',
#  'flashaafp.com',
#  'means',
#  'included',
#  'own',
#  'fall',
#  'immediately',
#  'apparently',
#  'done',
#  'hoping',
#  'previously',
#  'outside',
#  'leave',
#  'http://www.nifc.gov/',
#  'everyone',
#  'endtag',
#  'if',
#  'more',
#  'unlike',
#  'kept',
#  'none',
#  'seems',
#  'working',
#  'usual',
#  'give',
#  'appears',
#  'pyoot',
#  'not',
#  'initially',
#  'suggests',
#  'asked',
#  'explained',
#  'less',
#  'room',
#  'supposedly',
#  'than',
#  'keep',
#  'ooooooooooooooooooooooooooooooooooooooo',
#  'realized',
#  'several',
#  'during',
#  'decade',
#  'hnkj',
#  'rohch',
#  'around',
#  'look',
#  'provided',
#  'hence',
#  'without',
#  'similar',
#  'how',
#  'nokiacorp',
#  'three',
#  'hardly',
#  'consequently',
#  'expect',
#  'always',
#  'along',
#  'couple',
#  'was',
#  'maybe',
#  'early',
#  'drohs',
#  'second',
#  'them',
#  'shortly',
#  'shows',
#  'since',
#  'gwahng',
#  'thus',
#  'suggesting',
#  'say',
#  'should',
#  'takes',
#  'recent',
#  'able',
#  'see',
#  'grahts',
#  'half',
#  'moving',
#  'neither',
#  'with',
#  'he',
#  'made',
#  'contrast',
#  'spoolname',
#  'turning',
#  'wrldcom',
#  'nonetheless',
#  'changed',
#  'everything',
#  'goes',
#  'other',
#  'each',
#  'needed',
#  'five',
#  'current',
#  'mean',
#  'full',
#  'importantly',
#  'tuhv',
#  'else',
#  'apart',
#  'six',
#  'previous',
#  'whereas',
#  '40',
#  'on',
#  'www.caib.us',
#  'explaining',
#  'continued',
#  'dellcptr',
#  'being',
#  'keeping',
#  'expected',
#  'heading',
#  'timewrn',
#  'enough',
#  'whenever',
#  'like',
#  'longer',
#  'called',
#  'move',
#  'nearly',
#  'ever',
#  'started',
#  '50',
#  'fortunately',
#  'good',
#  '12',
#  'due',
#  'notably',
#  '—',
#  'something',
#  'need',
#  '25',
#  'saying',
#  'beyond',
#  '?',
#  '_',
#  'better',
#  'too',
#  'intended',
#  'determined',
#  'convinced',
#  'planned',
#  'many',
#  'within',
#  'is',
#  'such',
#  'pushed',
#  'thanks',
#  'places',
#  '16',
#  'eight',
#  'waiting',
#  '1997',
#  'got',
#  'resulted',
#  'figured',
#  '2004',
#  'therefore',
#  'close',
#  'stay',
#  '1999',
#  'http://www.opel.com',
#  'actual',
#  'talking',
#  'hahlt',
#  'added',
#  'indnsia',
#  'home',
#  'usually',
#  'eventually',
#  'staying',
#  'basically',
#  'wait',
#  'describing',
#  'hoped',
#  'returning',
#  'stands',
#  'including',
#  'dj025b',
#  'genlelec',
#  'gave',
#  'afternoon',
#  'these',
#  'cost',
#  'stayed',
#  'outset',
#  'must',
#  '1998',
#  'approached',
#  'know',
#  '2005',
#  'essentially',
#  'four',
#  'been',
#  'whether',
#  'reportedly',
#  'does',
#  'inside',
#  'third',
#  'opening',
#  'clear',
#  'wc2003-sri',
#  'suggest',
#  '2003',
#  'unlikely',
#  '2002',
#  'be',
#  "n't",
#  'wo',
#  'certain',
#  'normally',
#  'particularly',
#  'nangk',
#  'offered',
#  'morning',
#  'picked',
#  'has',
#  'anything',
#  'idea',
#  'originally',
#  'otherwise',
#  '1996',
#  'return',
#  'concerned',
#  'asking',
#  'happened',
#  'nine',
#  'area',
#  'never',
#  'zhadh',
#  'includes',
#  'tehf',
#  '11',
#  'allowed',
#  'monday',
#  'occasion',
#  '2001',
#  'hours',
#  'break',
#  'continuing',
#  'to',
#  'tissottiming.com',
#  'finding',
#  'mind',
#  'zheed',
#  'getting',
#  'over',
#  'knowing',
#  'lg03',
#  'change',
#  'handful',
#  'two',
#  'looks',
#  'coincidentally',
#  'believed',
#  'wc2003-wis',
#  'merely',
#  'obviously',
#  'seven',
#  'spot',
#  'telling',
#  'afterwards',
#  'follow',
#  'july',
#  'friday',
#  'quite',
#  'hand',
#  'insisted',
#  'work',
#  '1995',
#  'location',
#  'april',
#  'march',
#  'simultaneously',
#  'needs',
#  'january',
#  'november',
#  'call',
#  'september',
#  'chose',
#  '13',
#  'twice',
#  'reminded',
#  'makes',
#  'big',
#  '2007',
#  'things',
#  'view',
#  'lot',
#  'began',
#  'preparing',
#  'remember',
#  'behind',
#  'typical',
#  'will',
#  'marked',
#  'allowing',
#  '...',
#  '60',
#  '14',
#  'long',
#  'thing',
#  'undoubtedly',
#  '206-448-8135',
#  'whatever',
#  'thursday',
#  'aim',
#  'evening',
#  'tuesday',
#  'managed',
#  'have',
#  'opened',
#  'referred',
#  '2000',
#  'ended',
#  'spite',
#  'djdam',
#  'whilst',
#  'preceded',
#  'entered',
#  'concluded',
#  'gives',
#  'ones',
#  'doing',
#  '35',
#  'vicinity',
#  'surely',
#  'evident',
#  'muhlt',
#  'returned',
#  'brings',
#  'entire',
#  'indicated',
#  'had',
#  'unusual',
#  'calls',
#  'believe',
#  'offering',
#  'clearly',
#  'midst',
#  'possible',
#  'no',
#  'best',
#  'appear',
#  'moved',
#  'talk',
#  'whose',
#  'puts',
#  'chance',
#  'anywhere',
#  'away',
#  'ready',
#  'down',
#  'calling',
#  'summer',
#  'sunday',
#  'whole',
#  '17',
#  'nowhere',
#  'tried',
#  'imagine',
#  'past',
#  'interestingly',
#  'knew',
#  'hold',
#  'presented',
#  'october',
#  '28',
#  'available',
#  'appeared',
#  'include',
#  "doo'ah",
#  'elsewhere',
#  'assuming',
#  'definitely',
#  'noticed',
#  'david.lazarus@latimes.com',
#  'wednesday',
#  'allow',
#  'goals_none',
#  'arguing',
#  'kd94',
#  'held',
#  'think',
#  'wuhr',
#  'june',
#  'initial',
#  '28aou94',
#  'regard',
#  'rehts',
#  'alumhg',
#  'hope',
#  'choice',
#  'moment',
#  'mention',
#  'future',
#  'evidently',
#  'resulting',
#  'incidentally',
#  'arrival',
#  'drop',
#  'happens',
#  'bb97',
#  'involved',
#  'considered',
#  'combined',
#  'check',
#  'focused',
#  'ultimately',
#  'off',
#  'anyone',
#  'chosen',
#  'required',
#  'explain',
#  'acknowledged',
#  'want',
#  'trying',
#  'little',
#  'lastly',
#  'kd95',
#  'wake',
#  'enabled',
#  'point',
#  'generally',
#  '2006',
#  '21',
#  'oly-2004-tennis',
#  'thinks',
#  'fruj',
#  'begun',
#  'zuraimi',
#  'focus',
#  'starts',
#  'evidenced',
#  'tahsh',
#  '1993',
#  "'ll",
#  'marykane2000',
#  'continues',
#  'nethrlnds',
#  'shuhn',
#  'standing',
#  'doubt',
#  'plans',
#  'hard',
#  'conjunction',
#  'plenty',
#  'nearby',
#  'saturday',
#  'fahnt',
#  'consider',
#  '24',
#  'prepared',
#  'pyahng',
#  'tehz',
#  'trouble',
#  'sought',
#  'subject',
#  'left',
#  'late',
#  'aforementioned',
#  '31',
#  'date',
#  'described',
#  'bohld',
#  'often',
#  '22',
#  'wants',
#  'found',
#  'learned',
#  'spent',
#  'oly-2004-cycling',
#  'august',
#  'wherein',
#  '150',
#  'typically',
#  'small',
#  'december',
#  'tell',
#  'tihg',
#  'ends',
#  'knows',
#  '19',
#  'believes',
#  'can',
#  'seemed',
#  'kd96',
#  'respectively',
#  'through',
#  'alumal',
#  'used',
#  'nor',
#  '80',
#  'entering',
#  '27',
#  'tvtonightnytsyn.com',
#  'known',
#  'helped',
#  'conversely',
#  'question',
#  'established',
#  '23',
#  'wanting',
#  'sometimes',
#  'promised',
#  'alongside',
#  '1514.25',
#  '206-448-8004',
#  'dashst',
#  'explains',
#  'myoot',
#  'quickly',
#  'latest',
#  'success',
#  '0080ff',
#  'very',
#  'met',
#  'revealed',
#  'halfway',
#  'fourth',
#  '90',
#  'ahead',
#  'regardless',
#  'a',
#  'until',
#  'country',
#  'stated',
#  '”',
#  'begin',
#  'really',
#  'frequently',
#  'times',
#  'short',
#  '2008',
#  'happen',
#  'ten',
#  'remembered',
#  '1994',
#  'stop',
#  'changing',
#  "'d",
#  'difficult',
#  'new',
#  'suddenly',
#  'sorts',
#  'vrih',
#  '.000661',
#  'aware',
#  'hahj',
#  'viewed',
#  'failed',
#  'unable',
#  'reasons',
#  'i-qula',
#  'requested',
#  'shown',
#  '.000660',
#  'showing',
#  'separate',
#  'ask',
#  'large',
#  'oly-2004-gymnastics',
#  'dropping',
#  'talked',
#  'filled',
#  'mentioned',
#  'unless',
#  'stand',
#  'aside',
#  'somewhere',
#  'spring',
#  'participants',
#  'vruhl',
#  'ca',
#  'vwahr',
#  '.000435',
#  'near',
#  '3.7506',
#  'dozen',
#  'rehz',
#  'let',
#  'paid',
#  'worked',
#  'guess',
#  '18',
#  'passed',
#  'february',
#  'grij',
#  'claiming',
#  '74723,3507',
#  '26',
#  'dihg',
#  'push',
#  'remainder',
#  'him',
#  'tyahn',
#  'created',
#  'further',
#  'dropped',
#  'compared',
#  'enabling',
#  'lately',
#  'raised',
#  'sometime',
#  'agreed',
#  'easy',
#  'indicating',
#  'pointing',
#  'purpose',
#  'precisely',
#  'ought',
#  'remarked',
#  'reduced',
#  '[',
#  'decades',
#  'yr.ago',
#  'partly',
#  'rohvsk',
#  'describe',
#  'oly-2004-fhockey',
#  'lots',
#  'vahlz',
#  'anticipated',
#  'offers',
#  'moves',
#  'we',
#  'nobody',
#  'office',
#  'nytfileitnotes.ap.org',
#  'etc.',
#  'significant',
#  'syreglobe.com',
#  '29',
#  'plus',
#  'vega@globe.com',
#  'original',
#  'unclear',
#  'any',
#  'additional',
#  'primarily',
#  '48',
#  'reflected',
#  'forcing',
#  'nuhv',
#  'gwih',
#  'enter',
#  'subsequently',
#  'sitting',
#  'job',
#  'emerged',
#  'extended',
#  '1987',
#  'namely',
#  'ways',
#  'difference',
#  'surprised',
#  '.000105',
#  'planning',
#  'charge',
#  'plan',
#  'twenty',
#  'noonz',
#  'locals',
#  'subsequent',
#  'theirs',
#  'implying',
#  '5',
#  'itself',
#  'pulled',
#  'pre',
#  'prompted',
#  'continue',
#  'approaching',
#  'frontpage-1stld',
#  'you',
#  'hopes',
#  'says',
#  'realize',
#  'worried',
#  'worse',
#  'pointed',
#  'providing',
#  'or',
#  'paying',
#  'arrive',
#  'janlgardner@yahoo.com',
#  '70',
#  'building',
#  'thinking',
#  'oly-2004-box',
#  'scene',
#  'terms',
#  'fifth',
#  'letting',
#  'whom',
#  'notice',
#  'thirty',
#  'jahch',
#  'surprise',
#  'consequence',
#  '75',
#  'throughout',
#  'person',
#  'likes',
#  'experience',
#  'd00l',
#  'leading',
#  'absence',
#  'believing',
#  'folks',
#  'nowadays',
#  'lose',
#  'permitted',
#  'insisting',
#  'amount',
#  'larger',
#  'breaking',
#  '1990s',
#  'owing',
#  'i.e.',
#  'sihp',
#  'deciding',
#  'important',
#  'gweye',
#  'stuck',
#  'using',
#  'show',
#  'placing',
#  'encouraged',
#  '2009',
#  'remains',
#  'extent',
#  'dealing',
#  'officials',
#  'dec.',
#  '22-758-826',
#  'dehz',
#  'focusing',
#  'turns',
#  '7',
#  'about',
#  'business',
#  'from',
#  'dj025u',
#  'mostly',
#  'boasting',
#  'maintained',
#  'stopped',
#  'aiming',
#  'thereafter',
#  'x.xx.xx.xx.x',
#  'true',
#  'course',
#  'pushing',
#  'comparable',
#  'happy',
#  'benefit',
#  'number',
#  'indicate',
#  'promise',
#  'effort',
#  'dozens',
#  'thruh',
#  'forced',
#  'transformed',
#  ...]

# %%
topic1_embedding + embeddings_dict['hotel']
# Out:
# array([ 2.06119996e-02,  3.29100013e-01, -1.61889996e-02, -6.75129965e-02,
#         1.01889998e-01,  2.12530002e-01,  7.27069974e-02,  1.54330004e-02,
#        -2.12040007e-01, -8.09279978e-01,  3.52129996e-01, -6.94869995e-01,
#         8.27359974e-01,  4.32579994e-01, -8.07330012e-02,  1.29879996e-01,
#         5.43759987e-02, -4.90100011e-02, -1.02229998e-01, -1.24899998e-01,
#        -7.11199999e-01,  2.25390002e-01,  4.26979996e-02,  1.11759998e-01,
#         2.25510001e-01, -6.46630004e-02, -1.93059996e-01,  1.92019999e-01,
#        -9.64720026e-02, -3.15369993e-01,  5.94129980e-01,  4.05490011e-01,
#        -3.55919987e-01,  3.80560011e-01, -2.56240010e-01,  2.03899994e-01,
#        -2.59669989e-01, -2.11339995e-01, -7.17910007e-02, -8.07049990e-01,
#        -9.84300017e-01,  7.76130036e-02, -4.83560003e-02,  9.44469988e-01,
#         3.82459998e-01, -1.03110000e-01,  4.55509990e-01, -3.52500007e-02,
#        -2.74379998e-01, -2.62110005e-03,  1.66580006e-01, -1.03820002e+00,
#         1.99469998e-01,  1.06990002e-01,  3.62019986e-01,  1.93660006e-01,
#        -3.26739997e-01,  3.97579998e-01, -2.20410004e-01, -7.29900002e-02,
#         1.47359997e-01, -1.38310000e-01, -1.95280001e-01,  5.31000018e-01,
#         1.26959998e-02, -2.76690006e-01,  3.58489990e-01, -1.99680001e-01,
#        -3.93260002e-01, -7.06380010e-01,  3.30500007e-02,  2.62430012e-01,
#         6.80249989e-01,  2.52180010e-01, -4.60029989e-01,  6.16910011e-02,
#         2.03270003e-01, -6.06379986e-01,  1.13909997e-01, -3.37570012e-01,
#        -1.25300005e-01,  3.44810009e-01, -6.16800003e-02,  4.20949996e-01,
#         5.45569994e-02, -3.28619987e-01, -5.79299986e-01, -5.07570028e-01,
#         7.96180032e-03, -3.07020009e-01, -1.15010003e-03,  7.67600015e-02,
#         2.47659996e-01,  7.96760023e-01,  1.93210006e-01,  3.38519990e-01,
#         3.34030002e-01, -6.09440029e-01,  2.10539997e-01, -2.75660008e-01,
#        -6.19270027e-01,  1.81299999e-01,  1.71829998e-01, -2.62890011e-01,
#        -3.90379995e-01,  1.99630000e-02,  1.16020001e-01, -2.75869995e-01,
#         4.37900007e-01, -4.61240001e-02,  3.56269985e-01, -1.70240000e-01,
#         3.37330014e-01,  3.66019994e-01,  3.87919992e-01,  2.84369998e-02,
#        -1.79769993e-01, -3.13909985e-02, -3.93929988e-01, -2.09580004e-01,
#         7.83840001e-01, -1.38669997e-01,  1.59830004e-02,  2.16710001e-01,
#        -2.57050008e-01, -5.03989995e-01, -2.98599988e-01, -1.41489998e-01,
#         3.79270017e-02, -8.20599973e-01,  4.21090007e-01,  5.22880018e-01,
#         1.50490001e-01, -5.22099972e-01,  2.93930005e-02, -1.14720002e-01,
#        -4.16869998e-01, -2.98319995e-01, -3.14870000e-01, -4.66239989e-01,
#        -6.73030019e-01, -3.51520002e-01, -1.70139998e-01,  1.04600000e+00,
#        -1.60429999e-01, -2.50620008e-01,  4.35750008e-01,  1.40970007e-01,
#        -3.66769999e-01,  5.75079978e-01,  8.61630023e-01,  5.21380007e-01,
#        -1.78420007e-01,  2.19880000e-01,  3.81029993e-02, -6.51379973e-02,
#        -3.52759995e-02,  1.63289998e-02, -1.60789993e-02, -1.95040002e-01,
#         1.09780002e+00, -3.10589999e-01, -1.35049999e-01, -2.46370003e-01,
#        -4.09840010e-02,  1.64810002e-01, -1.03780001e-01, -8.21869969e-02,
#         2.14279994e-01,  4.64249998e-01, -5.45910001e-01, -1.10830002e-01,
#        -5.47330007e-02, -2.41799995e-01, -5.40690005e-01, -2.52609998e-02,
#        -3.74890000e-01,  3.56750011e-01,  2.10360009e-02, -1.19670004e-01,
#         2.87339985e-01,  1.01790000e-02, -2.32429996e-01, -9.00309980e-02,
#         3.43419984e-02,  8.08919966e-02, -5.62030002e-02,  5.72990000e-01,
#        -2.81129986e-01,  4.78280008e-01,  1.06159997e+00,  3.19130003e-01,
#        -7.98430026e-01, -6.90180004e-01, -7.35279992e-02, -4.22190011e-01,
#        -6.39490008e-01, -1.62429996e-02, -7.92460024e-01,  3.26029986e-01,
#         1.10990000e+00, -5.08040011e-01, -2.65329987e-01,  2.10800003e-02,
#        -3.52490008e-01,  4.21239994e-02,  2.91640013e-01,  1.20499998e-01,
#         3.87840003e-01, -6.20019972e-01, -2.05919996e-01,  1.66219994e-01,
#         6.00240007e-02, -3.45490009e-01,  6.67039990e-01,  5.23239970e-01,
#         2.43550003e-01, -7.02099979e-01, -3.98450010e-02, -9.50970035e-03,
#         6.87020004e-01, -9.31390002e-02,  3.04529995e-01,  6.24170005e-01,
#        -4.75019991e-01,  1.02720000e-01, -2.48750001e-01, -5.13059974e-01,
#        -2.44900007e-02, -6.22959994e-02,  1.27399996e-01, -4.81709987e-01,
#         1.52869999e-01,  1.46960005e-01,  9.44639981e-01, -5.89759983e-02,
#         3.13959986e-01,  1.97459996e-01, -3.71859998e-01,  8.42309967e-02,
#        -1.36960000e-01, -6.45060018e-02,  2.03569993e-01,  1.56700000e-01,
#         3.18529993e-01, -2.49439999e-01,  1.97310001e-01, -3.70819986e-01,
#        -6.71620011e-01,  6.87209964e-02,  4.42939997e-01,  1.23549998e-01,
#         4.41610008e-01,  4.49829996e-01,  6.34359987e-03, -3.46760005e-02,
#        -3.13540012e-01,  2.74370015e-01,  4.94700015e-01, -5.42299986e-01,
#        -3.95960003e-01, -2.66389996e-01,  1.03070000e-02, -2.37120003e-01,
#        -1.81840003e-01, -3.73079985e-01,  7.68580019e-01, -8.50080028e-02,
#         4.74759996e-01, -3.12649995e-01, -3.13719988e-01, -4.83209997e-01,
#        -3.06989998e-01,  5.00559993e-02,  5.18469989e-01, -3.93759996e-01,
#        -2.00769997e+00,  5.54400027e-01, -1.08199999e-01, -2.33170003e-01,
#        -4.11440015e-01,  6.22109994e-02,  3.51080000e-01, -6.83000028e-01,
#        -2.48799995e-01,  5.57640016e-01,  3.15890014e-01,  7.26879984e-02,
#        -4.43069994e-01, -4.35710013e-01,  5.34919977e-01,  9.86199975e-02,
#        -6.99790001e-01,  1.49560004e-01,  6.74929991e-02, -8.46560001e-02,
#         7.40320012e-02, -8.01189989e-02, -2.02319995e-01,  6.78889975e-02])

# %%
find_closest_embeddings(
(embeddings_dict['hotel']+embeddings_dict['room']+embeddings_dict['area']+embeddings_dict['time']
+embeddings_dict['location'])/5 )[:5]
# Out:
# ['where', 'same', '.', '__________________________________', 'prohertrib']

# %%
def topic_cosine(list1, list2):
    
    topic1_embedding = np.array([0.00]*300) 
    topic2_embedding = np.array([0.00]*300)
    
    for i in list1:
        topic1_embedding += embeddings_dict[i.lower()]
        
    topic1_embedding = topic1_embedding/len(list1)
        
    for i in list2:
        topic2_embedding += embeddings_dict[i.lower()]
    
    topic2_embedding = topic2_embedding/len(list2)
    
    return (1 - spatial.distance.cosine(topic1_embedding, topic2_embedding))

# %%
insta_topic = {
    'skyline':['skyscraper','block','cloud','daytime','world'],
    'landscape':['nature','flower','natural','landscape','leisure'],
    'events':['rectangle','electric','tickets','brand','circle'],
    'traffic':['vehicle','automotive','infrastructure','lighting','wheel'],
    'people':['gesture','happy','event','yorkers'],
    'city_scapes':['bridge','facade','light','lighting','window']  }

# %%
blog_topic = {
    'Quarantine': ['Quarantine', 'travel', 'vaccine', 'rule', 'may', '2021', 'mask'],
    'Accommodation': ['restaurant', 'food', 'hotel', 'great', 'bar','room'],
    'train': ['subway', 'train', 'people', 'station', 'time'],
    'Leisure': ['park', 'walk', 'central', 'time', 'street', 'brooklyn', 'jazz'],
    'Crime': ['crime', 'people', 'homeless', 'like'],
    'air_travel': ['hotel', 'car', 'flight', 'airport', 'jfk','parking']  }

# %%
df = pd.DataFrame(columns = insta_topic.keys(), index = blog_topic.keys() ).fillna(0.00)

for i in df.index:
    for j in df.columns.values:
        df.loc[i,j] = topic_cosine(blog_topic[i], insta_topic[j])

# %%
df
# Out:
#                 skyline  landscape    events   traffic    people  city_scapes
# Quarantine     0.318222   0.297941  0.309909  0.248469  0.269528     0.221211
# Accommodation  0.400450   0.348191  0.439868  0.333048  0.359699     0.452201
# train          0.461352   0.258759  0.411337  0.379573  0.396066     0.439456
# Leisure        0.480544   0.409170  0.434882  0.269236  0.420626     0.486892
# Crime          0.421768   0.322014  0.250135  0.239437  0.498479     0.251760
# air_travel     0.418665   0.173377  0.403170  0.436186  0.262286     0.422816

# %%
import seaborn as sns

sns.heatmap(df,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.max(axis=1)
# Out:
# Quarantine       0.318222
# Accommodation    0.452201
# train            0.461352
# Leisure          0.486892
# Crime            0.498479
# air_travel       0.436186
# dtype: float64

# %%
df2 = pd.DataFrame(index = blog_topic.keys() ).fillna(0.00)

# %%
list = []
for i in blog_topic.keys():
    list += blog_topic[i]
    
df2 = pd.DataFrame(index = ['blog'], columns = insta_topic.keys()).fillna(0.00)

for i in df2.columns.values:
    df2[i] = topic_cosine(list, insta_topic[i])
    
df2
# Out:
#       skyline  landscape    events   traffic    people  city_scapes
# blog  0.56145    0.40402  0.514427  0.433124  0.485627     0.524011

# %%
list = []

for i in insta_topic.keys():
    list += insta_topic[i]
    
df3 = pd.DataFrame(index = ['insta'], columns = blog_topic.keys()).fillna(0.00)

for i in df2.columns.values:
    df3[i] = topic_cosine(list, blog_topic[i])
    
df3
# Out:
#        Quarantine  Accommodation     train   Leisure     Crime  air_travel
# insta    0.401751       0.567476  0.568646  0.603998  0.468547    0.520344
